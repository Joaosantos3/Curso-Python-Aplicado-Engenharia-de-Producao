# %% [markdown]
# <a href="https://colab.research.google.com/github/Joaosantos3/Curso-Python-Aplicado-Engenharia-de-Producao/blob/main/Parte1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Análise Exploratória e Limpeza
#
# Bem-vindo à seção de **Análise Exploratória e Limpeza**! 🎉 Nesta etapa do curso, vamos mergulhar em algumas das habilidades mais essenciais para qualquer cientista de dados ou analista.
#
# ### O que vamos aprender?
#
# Nesta seção de 4 horas, abordaremos várias técnicas e métodos para preparar seus dados para análise. Vamos usar a poderosa biblioteca `pandas` para:
#
# - **Carregar dados** de diferentes fontes e visualizá-los rapidamente.
# - **Entender os tipos de dados** e como convertê-los entre diferentes formatos.
# - **Identificar e tratar dados repetidos**, garantindo que sua análise não seja distorcida.
# - **Lidar com dados faltantes**, aprendendo técnicas para substituir ou remover valores ausentes.
# - **Aplicar métodos de filtragem**, usando filtros básicos, consultas (`query`), e máscaras booleanas.
# - **Usar métodos de slice** (`loc` e `iloc`) para acessar partes específicas do DataFrame.
# - **Combinar métodos** para uma limpeza de dados mais eficiente e robusta.
# - **Realizar estatísticas descritivas**, entendendo as características principais dos seus dados.
#
# ### Por que isso é importante?
#
# A análise exploratória e a limpeza de dados são etapas cruciais no processo de análise e ciência de dados. Dados limpos e bem entendidos são fundamentais para garantir a precisão e a confiabilidade das suas análises e modelos. Além disso, um bom entendimento dos dados pode revelar insights valiosos que podem orientar decisões de negócios e estratégias.
#
# Prepare-se para sujar as mãos e transformar dados brutos em informações valiosas! 🚀
#
# Vamos começar com o **carregamento de dados com Pandas**.

# %% [markdown]
# # Acessando o Google Drive
#
# Primeiro, montamos o Google Drive no Google Colab para acessar os arquivos diretamente.
#
# ```python
# from google.colab import drive
# drive.mount('/content/drive')
#
# # Agora, você pode acessar seus arquivos no Google Drive
# # Exemplo: /content/drive/My Drive/arquivo.csv

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Fazendo importação do `pandas` e leitura de arquivos
#
# Aqui vamos importar a biblioteca e daremos um apelido a ela como **pd**.

# %%
import pandas as pd

# %% [markdown]
# ### Resumo das Funções de Leitura
#
# - **CSV:** `pd.read_csv('/content/drive/My Drive/arquivo.csv')`
# - **Excel:** `pd.read_excel('/content/drive/My Drive/arquivo.xlsx', sheet_name='Planilha1')`
# - **JSON:** `pd.read_json('/content/drive/My Drive/arquivo.json')`
# - **SQL:** `pd.read_sql_query('SELECT * FROM tabela', conexão)`
# - **Parquet:** `pd.read_parquet('/content/drive/My Drive/arquivo.parquet')`
#
# ### Exemplos Práticos de Importação de Dados
#
# ```markdown
# # Exemplos Práticos de Importação de Dados
# import pandas as pd
# # Lendo um arquivo CSV
# df_csv = pd.read_csv('/content/drive/My Drive/arquivo.csv')

# %%
df_excel=pd.read_excel("/content/drive/MyDrive/Python para Produção/Adidas US Sales Datasets.xlsx")
df_csv=pd.read_csv("/content/drive/MyDrive/Python para Produção/Adidas US Sales Datasets.csv",delimiter=';',encoding='utf-8')

# %%
df_excel.head(3)
# Out:
#   Retailer  Retailer ID Invoice Date     Region     State      City  \
# 0   Kohl's      1185732   2020-01-01  Northeast  New York  New York
# 1   Kohl's      1185732   2020-01-02  Northeast  New York  New York
# 2   Kohl's      1185732   2020-01-03  Northeast  New York  New York
#
#                    Product  Price per Unit  Units Sold  Total Sales  \
# 0    Men's Street Footwear            50.0        1200      60000.0
# 1  Men's Athletic Footwear            50.0        1000      50000.0
# 2  Women's Street Footwear            40.0        1000      40000.0
#
#    Operating Profit  Operating Margin Sales Method
# 0           30000.0              0.50     In-store
# 1           15000.0              0.30     In-store
# 2           14000.0              0.35     In-store

# %%
df_csv.head(3)
# Out:
#   Retailer  Retailer ID Invoice Date     Region     State      City  \
# 0   Kohl's      1185732   01/01/2020  Northeast  New York  New York
# 1   Kohl's      1185732   02/01/2020  Northeast  New York  New York
# 2   Kohl's      1185732   03/01/2020  Northeast  New York  New York
#
#                    Product  Price per Unit  Units Sold  Total Sales  \
# 0    Men's Street Footwear            50.0         1.2      60000.0
# 1  Men's Athletic Footwear            50.0         1.0      50000.0
# 2  Women's Street Footwear            40.0         1.0      40000.0
#
#    Operating Profit  Operating Margin Sales Method
# 0           30000.0              0.50     In-store
# 1           15000.0              0.30     In-store
# 2           14000.0              0.35     In-store

# %% [markdown]
# ###Tipos de Dados em Python
# ###Python possui os seguintes tipos de dados principais:
#
# **Números**:
#
# - Inteiros (int): números inteiros, por exemplo, 1, 10, -5.
# - Ponto flutuante (float): números decimais, por exemplo, 3.14, 2.5, -0.1.
# - Números complexos (complex): números com uma parte real e uma imaginária, por exemplo, 3+2j.
#
# **Booleanos**:
#
# - bool: Valores booleanos True e False, utilizados em expressões lógicas.
#
# **Sequências**:
#
# - Strings (str): Sequência de caracteres, por exemplo, "Olá, mundo!".
# - Listas (list): Sequência mutável de elementos, por exemplo, [1, 2, 3, 4].
# - Tuplas (tuple): Sequência imutável de elementos, por exemplo, (1, 2, 3).
#
# **Conjuntos**:
#
# - Conjuntos (set): Coleção não ordenada de elementos únicos, por exemplo, {1, 2, 3}.
# - Dicionários (dict): Coleção de pares chave-valor, por exemplo, {'nome': 'João', 'idade': 30}.
#
# **Entre outros formatos**:
# - Datetime (datetime64): Formato de Data e Hora, exemplo: '2005-02-25'
#
#
# #### ⏳ Os formato dos dados terão grande importância a medida que trabalhamos com grandes conjuntos, gerando impacto no tempo de processamento e principalmente no armazenamento de dados na memória do computador. Para médio conjunto de dados e superiores (como BigData) trabalhar otimizando armazenagem de dados poupa tempo e dinheiro 💸
#
# Link: [Artigo_Linkedin](https://www.linkedin.com/feed/update/urn:li:activity:7206263934461325313?updateEntityUrn=urn%3Ali%3Afs_updateV2%3A%28urn%3Ali%3Aactivity%3A7206263934461325313%2CFEED_DETAIL%2CEMPTY%2CDEFAULT%2Cfalse%29)

# %%
df_excel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9650 entries, 0 to 9649
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Retailer          9650 non-null   object
#  1   Retailer ID       9650 non-null   int64
#  2   Invoice Date      9650 non-null   datetime64[ns]
#  3   Region            9650 non-null   object
#  4   State             9650 non-null   object
#  5   City              9650 non-null   object
#  6   Product           9643 non-null   object
#  7   Price per Unit    9640 non-null   float64
#  8   Units Sold        9650 non-null   int64
#  9   Total Sales       9645 non-null   float64
#  10  Operating Profit  9647 non-null   float64
#  11  Operating Margin  9636 non-null   float64
#  12  Sales Method      9650 non-null   object
# dtypes: datetime64[ns](1), float64(4), int64(2), object(6)
# memory usage: 980.2+ KB

# %%
df=df_excel.copy()
#df=pd.read_csv("/content/drive/MyDrive/Python para Produção/Adidas US Sales Datasets.csv",delimiter=';',encoding='utf-8')

# %%
df_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9650 entries, 0 to 9649
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Retailer          9650 non-null   object
#  1   Retailer ID       9650 non-null   int64
#  2   Invoice Date      9650 non-null   object
#  3   Region            9650 non-null   object
#  4   State             9650 non-null   object
#  5   City              9650 non-null   object
#  6   Product           9643 non-null   object
#  7   Price per Unit    9640 non-null   float64
#  8   Units Sold        9650 non-null   float64
#  9   Total Sales       9645 non-null   float64
#  10  Operating Profit  9647 non-null   float64
#  11  Operating Margin  9636 non-null   float64
#  12  Sales Method      9650 non-null   object
# dtypes: float64(5), int64(1), object(7)
# memory usage: 980.2+ KB

# %% [markdown]
# ###Alterando tipo de dados da coluna Invoice Data para Datetime
#
#
#
# ```python
# df_csv['Invoice Date']=pd.to_datetime(df_csv['Invoice Date'].values,format='%d/%m/%Y')
# ```

# %%
df_csv['Invoice Date']=pd.to_datetime(df_csv['Invoice Date'].values,format='%d/%m/%Y')

# %%
df_csv['Retailer ID']=df_csv['Retailer ID'].astype(str)
df_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9650 entries, 0 to 9649
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Retailer          9650 non-null   object
#  1   Retailer ID       9650 non-null   object
#  2   Invoice Date      9650 non-null   datetime64[ns]
#  3   Region            9650 non-null   object
#  4   State             9650 non-null   object
#  5   City              9650 non-null   object
#  6   Product           9643 non-null   object
#  7   Price per Unit    9640 non-null   float64
#  8   Units Sold        9650 non-null   float64
#  9   Total Sales       9645 non-null   float64
#  10  Operating Profit  9647 non-null   float64
#  11  Operating Margin  9636 non-null   float64
#  12  Sales Method      9650 non-null   object
# dtypes: datetime64[ns](1), float64(5), object(7)
# memory usage: 980.2+ KB

# %% [markdown]
# ###Resumo breve das classes dos **PANDAS**
#
# No geral trabalhamos com dois tipos de classes do pandas, são elas: `pandas.core.series.Series` e `pandas.core.frame.DataFrame`.
#
# Um conjunto de séries organizadas com índices ou *index* e colunas *columns* formam um DataFrame.
#
# Existem métodos/funções específicas para cada classe. Essas funções implementadas facilitam muito o trabalho apresentando formas mais eficientes para manipular os dados.

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#   Retailer  Retailer ID Invoice Date     Region     State      City  \
# 0   Kohl's      1185732   2020-01-01  Northeast  New York  New York
# 1   Kohl's      1185732   2020-01-02  Northeast  New York  New York
# 2   Kohl's      1185732   2020-01-03  Northeast  New York  New York
# 3   Kohl's      1185732   2020-01-04  Northeast  New York  New York
# 4   Kohl's      1185732   2020-01-05  Northeast  New York  New York
#
#                      Product  Price per Unit  Units Sold  Total Sales  \
# 0      Men's Street Footwear            50.0        1200      60000.0
# 1    Men's Athletic Footwear            50.0        1000      50000.0
# 2    Women's Street Footwear            40.0        1000      40000.0
# 3  Women's Athletic Footwear            45.0         850      38250.0
# 4              Men's Apparel            60.0         900      54000.0
#
#    Operating Profit  Operating Margin Sales Method
# 0           30000.0              0.50     In-store
# ...

# %%
type(df['Retailer ID'])
# Out:
# pandas.core.series.Series

# %%
df['Retailer ID'].head()
# Out:
# 0    1185732
# 1    1185732
# 2    1185732
# 3    1185732
# 4    1185732
# Name: Retailer ID, dtype: int64

# %% [markdown]
# ### OUTRA VISÃO: TIPOS DE DADOS☝
#
# É de extrema importância compreeender os tipos de dados e significados deles em um conjunto.
#
# Existem vários tipos de dados, entre eles:
#
# 1. Dados Contínuos
# - Definição: Dados que podem assumir qualquer valor dentro de um intervalo contínuo. Não há gaps ou interrupções entre valores possíveis.
# - Exemplos: Altura, peso, temperatura, tempo.
# - Características:
# Representados geralmente por números reais.
# Podem ser medidos com precisão arbitrária.
# - Visualização comum: histogramas, gráficos de linhas, gráficos de dispersão.
#
# 2. Dados Discretos
# - Definição: Dados que podem assumir valores contáveis e específicos, geralmente inteiros.
# - Exemplos: Número de filhos, número de carros, quantidade de produtos vendidos.
# - Características:
# Representados geralmente por números inteiros.
# Há gaps entre valores possíveis.
# - Visualização comum: gráficos de barras, gráficos de linhas (para séries temporais discretas).
# 3. Dados Categóricos
# - Definição: Dados que representam categorias ou grupos distintos, sem ordem intrínseca.
# - Exemplos: Cores (vermelho, azul, verde), tipos de produtos, gêneros (masculino, feminino).
# - Características:
# Representados por rótulos ou nomes.
# Não há relacionamento quantitativo entre categorias.
# - Visualização comum: gráficos de barras, gráficos de pizza.
# 4. Dados Ordinais
# - Definição: Dados categóricos que possuem uma ordem intrínseca.
# - Exemplos: Classificação de satisfação (ruim, regular, bom, excelente), níveis educacionais (fundamental, médio, superior).
# - Características:
# Representados por rótulos ou nomes ordenados.
# Há uma ordem ou hierarquia, mas a diferença entre os níveis pode não ser uniforme.
# - Visualização comum: gráficos de barras, gráficos de linhas.
# 5. Dados Nominais
# - Definição: Subtipo de dados categóricos, onde não há uma ordem específica.
# - Exemplos: Cores, gêneros, marcas de carro.
# - Características:
# Representados por rótulos ou nomes.
# Não há ordem ou hierarquia.
# - Visualização comum: gráficos de barras, gráficos de pizza.
# 6. Dados Intervalares
# - Definição: Dados numéricos onde as diferenças entre os valores são significativas, mas não há um ponto zero verdadeiro.
# - Exemplos: Temperatura em Celsius ou Fahrenheit, datas.
# - Características:
# Representados por números reais.
# Permitem a adição e subtração, mas não a multiplicação e divisão.
# - Visualização comum: histogramas, gráficos de linhas.
# 7. Dados de Razão
# - Definição: Dados numéricos que possuem um ponto zero verdadeiro, permitindo todas as operações matemáticas.
# - Exemplos: Altura, peso, idade, tempo decorrido.
# - Características:
# Representados por números reais.
# Permitem todas as operações matemáticas.
# - Visualização comum: histogramas, gráficos de linhas, gráficos de dispersão.
#
# Para dados categóricos, é sempre interessante entender quantas categorias existem. Para isto usaremos uma função do `pandas`:
#
# ```python
# df.nunique()
# ```

# %%
df.nunique()
# Out:
# Retailer               5
# Retailer ID            5
# Invoice Date         724
# Region                 5
# State                 50
# City                  52
# Product                6
# Price per Unit       146
# Units Sold           360
# Total Sales         3479
# Operating Profit    6470
# Operating Margin     127
# Sales Method           3
# dtype: int64

# %%
df[['Retailer','Retailer ID']].groupby(by='Retailer').count()
# Out:
#                Retailer ID
# Retailer
# Amazon                 135
# Foot Locker            100
# Kohl's                9289
# Sports Direct          122
# West Gear                4

# %% [markdown]
# ###🌟DICA DE OURO🌟
# ####<font color=red>`Atenção para heranças do pandas DataFrame, sempre que for criar uma cópia, use COPY()!`<font/>
#
#
# **Link para estudo:**
# https://realpython.com/pandas-settingwithcopywarning/

# %%
#Criando DataFrame qualquer

data1=pd.DataFrame([['João',100,'MAT 137'],['Maria',60,'INF 101'],['José',70,'EPR 397']],columns=['Nome','Nota','Disciplina'])

# %%
data1
# Out:
#     Nome  Nota Disciplina
# 0   João   100    MAT 137
# 1  Maria    60    INF 101
# 2   José    70    EPR 397

# %%
data2=data1

# %%
data2['Disciplina']='ERRAR DE PROPÓSITO'

# %%
data1
# Out:
#     Nome  Nota          Disciplina
# 0   João   100  ERRAR DE PROPÓSITO
# 1  Maria    60  ERRAR DE PROPÓSITO
# 2   José    70  ERRAR DE PROPÓSITO

# %%
data1=pd.DataFrame([['João',100,'MAT 137'],['Maria',60,'INF 101'],['José',70,'EPR 397']],columns=['Nome','Nota','Disciplina'])

# %%
data3=data1.copy()

# %%
data3['Disciplina']=0

# %%
data3
# Out:
#     Nome  Nota  Disciplina
# 0   João   100           0
# 1  Maria    60           0
# 2   José    70           0

# %%
data1
# Out:
#     Nome  Nota Disciplina
# 0   João   100    MAT 137
# 1  Maria    60    INF 101
# 2   José    70    EPR 397

# %% [markdown]
# ###Máscara Booleana: Dominando para Manipular Dados
#
# **O que são Máscaras Booleanas?**
#
# As máscaras booleanas são ferramentas poderosas que permitem selecionar e manipular valores específicos em um conjunto de dados binários. Elas funcionam como filtros, permitindo que apenas os bits desejados passem por elas, enquanto os demais são bloqueados.
#
# Aqui, consideramos True e False como Binários ou Booleanos. As máscaras booleanas são a forma mais otimizada de filtragem.
#
# Ao invés de iterar com loops (`for` e `while`) e condicionais (`if` e `else`) sobre cada valor de uma matriz `numpy.Array` ou `pandas.DataFrame` nós, com base em uma ou várias condições, criamos uma `numpy.Array` ou `pd.DataFrame` ou `pd.Series` com valores *booleanos* e utilizamos como parâmetro de filtragem.
#
# - Vamos iniciar criar alguns máscaras e avaliar o resultado:
#
# ```python
#
# '''criar mascara, preço unitários maior que 40 dólares'''
# mascara1=df['Price per Unit']>40
#
# '''criar mascara, unidades vendidas menor ou igual a 800'''
# mascara2=df['Units Sold']<=800
#
# '''criar mascara, margem de lucro maior que 30%'''
# mascara3=df['Operating Margin']>0.3
#
# '''criar mascara, escolhi um varejista: Kohl's '''
# mascara_4=df['Retailer']=="Kohl's"
#
# '''criar mascara, múltiplas cidades: ['New York','Atlanta']'''
# mascara_5=df['City']==['New York','Atlanta']
#
# ```

# %%
'''criar mascara, preço unitários maior que 40 dólares'''
mascara1=df['Price per Unit']>40

'''criar mascara, unidades vendidas menor ou igual a 800'''
mascara2=df['Units Sold']>150

'''criar mascara, margem de lucro maior que 30%'''
mascara3=df['Operating Margin']>0.3

'''criar mascara, escolhi um varejista: Kohl's '''
mascara_4=df['Retailer']=="Kohl's"

'''criar mascara, múltiplas cidades: ['New York','Atlanta']'''
mascara_5=df['City'].isin(['New York','Atlanta'])

# %%
print("mascara1")
print(mascara1)
print()
print("mascara2")
print(mascara2)
# Out:
# mascara1
# 0        True
# 1        True
# 2       False
# 3        True
# 4        True
#         ...
# 9645     True
# 9646     True
# 9647     True
# 9648     True
# 9649    False
# Name: Price per Unit, Length: 9650, dtype: bool
#
# mascara2
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 9645    False
# 9646    False
# 9647     True
# 9648    False
# 9649    False
# Name: Units Sold, Length: 9650, dtype: bool

# %%
df[mascara2]
# Out:
#          Retailer  Retailer ID Invoice Date     Region          State  \
# 0          Kohl's      1185732   2020-01-01  Northeast       New York
# 1          Kohl's      1185732   2020-01-02  Northeast       New York
# 2          Kohl's      1185732   2020-01-03  Northeast       New York
# 3          Kohl's      1185732   2020-01-04  Northeast       New York
# 4          Kohl's      1185732   2020-01-05  Northeast       New York
# ...           ...          ...          ...        ...            ...
# 9616       Amazon      1189833   2021-09-17  Northeast  New Hampshire
# 9622  Foot Locker      1128299   2021-10-19  Northeast  New Hampshire
# 9634  Foot Locker      1128299   2021-12-17  Northeast  New Hampshire
# 9641  Foot Locker      1128299   2021-01-24  Northeast  New Hampshire
# 9647  Foot Locker      1128299   2021-02-22  Northeast  New Hampshire
#
#             City                    Product  Price per Unit  Units Sold  \
# ...

# %% [markdown]
# ###Outros métodos de filtragem: *where* e *query*
#
# Utilizamos o where quando aplicamos valores e mudanças a um `pd.DataFrame` ou `pd.Series` dada uma condição.
#
# ❗ATENÇÃO, OS VALORES FALSE NA MÁSCARA QUE SERÃO SUBSTITUÍDOS❗
# 🤓 AQUI, A LÓGICA É INVERTIDA!
#
# ```python
# #PARA UNIDADES VENDIDAS SUPERIORES A 1000, UNIDADES SUPERIORES RECEBEM 2000
# df[['Units Sold']].where(df['Units Sold']>1000,2000)
#
# '''usando o parâmetro inplace=True, o dataframe será alterado'''
# ```
# ❗NESTE CASO, OS VALORES > 1000 SERÃO MANTIDOS E <= 1000 SUBSTITUIDOS POR 2000❗

# %%
df[['Units Sold']].where(df['Units Sold']>1000,2000,inplace=False) #inplace=False não alteramos a fonte!
# Out:
#       Units Sold
# 0           1200
# 1           2000
# 2           2000
# 3           2000
# 4           2000
# ...          ...
# 9645        2000
# 9646        2000
# 9647        2000
# 9648        2000
# 9649        2000
#
# [9650 rows x 1 columns]

# %%
df.head()
# Out:
#   Retailer  Retailer ID Invoice Date     Region     State      City  \
# 0   Kohl's      1185732   2020-01-01  Northeast  New York  New York
# 1   Kohl's      1185732   2020-01-02  Northeast  New York  New York
# 2   Kohl's      1185732   2020-01-03  Northeast  New York  New York
# 3   Kohl's      1185732   2020-01-04  Northeast  New York  New York
# 4   Kohl's      1185732   2020-01-05  Northeast  New York  New York
#
#                      Product  Price per Unit  Units Sold  Total Sales  \
# 0      Men's Street Footwear            50.0        1200      60000.0
# 1    Men's Athletic Footwear            50.0        1000      50000.0
# 2    Women's Street Footwear            40.0        1000      40000.0
# 3  Women's Athletic Footwear            45.0         850      38250.0
# 4              Men's Apparel            60.0         900      54000.0
#
#    Operating Profit  Operating Margin Sales Method
# 0           30000.0              0.50     In-store
# ...

# %% [markdown]
# Algumas pessoas por associação a sistema de gerenciamento de bancos de dados SQL como MySQL, SQLite, PostreSQL, SQL Server preferem notação semelhante a consultas ou querys.
#
# ```python
# #CONSULTA COM UNIDADES VENDIDAS SUPERIORES A 1200
#
# df.query(" `Units Sold` > 1200").head()
#
# '''usando o parâmetro inplace=True, o dataframe será alterado'''
# ```

# %%
df.query(" `Units Sold` > 1200")
# Out:
#    Retailer  Retailer ID Invoice Date     Region     State      City  \
# 6    Kohl's      1185732   2020-01-07  Northeast  New York  New York
# 13   Kohl's      1185732   2020-01-25  Northeast  New York  New York
# 25   Kohl's      1185732   2020-02-06  Northeast  New York  New York
# 31   Kohl's      1185732   2020-03-04  Northeast  New York  New York
# 37   Kohl's      1185732   2020-03-10  Northeast  New York  New York
# 43   Kohl's      1185732   2020-03-16  Northeast  New York  New York
#
#                   Product  Price per Unit  Units Sold  Total Sales  \
# 6   Men's Street Footwear            50.0        1250      62500.0
# 13  Men's Street Footwear            50.0        1220      61000.0
# 25  Men's Street Footwear            60.0        1220      73200.0
# 31  Men's Street Footwear            60.0        1250      75000.0
# 37  Men's Street Footwear            60.0        1275      76500.0
# 43  Men's Street Footwear            60.0        1250      75000.0
#
# ...

# %%
df.query(" `Units Sold` > 500 & `State` == 'New York' ").head()
# Out:
#   Retailer  Retailer ID Invoice Date     Region     State      City  \
# 0   Kohl's      1185732   2020-01-01  Northeast  New York  New York
# 1   Kohl's      1185732   2020-01-02  Northeast  New York  New York
# 2   Kohl's      1185732   2020-01-03  Northeast  New York  New York
# 3   Kohl's      1185732   2020-01-04  Northeast  New York  New York
# 4   Kohl's      1185732   2020-01-05  Northeast  New York  New York
#
#                      Product  Price per Unit  Units Sold  Total Sales  \
# 0      Men's Street Footwear            50.0        1200      60000.0
# 1    Men's Athletic Footwear            50.0        1000      50000.0
# 2    Women's Street Footwear            40.0        1000      40000.0
# 3  Women's Athletic Footwear            45.0         850      38250.0
# 4              Men's Apparel            60.0         900      54000.0
#
#    Operating Profit  Operating Margin Sales Method
# 0           30000.0              0.50     In-store
# ...

# %% [markdown]
# ###Dados Duplicados
# #####Imagine um conjunto de dados que contém informações sobre clientes, como nome, endereço e e-mail. Se um mesmo cliente aparecer várias vezes, com registros idênticos ou inconsistentes, esses registros são considerados duplicados.
#
# #####Dados duplicados podem surgir por diversos motivos, como erros na coleta de dados, integração de diferentes fontes ou simplesmente descuido. Se não forem tratados adequadamente, podem trazer diversos problemas:
#
# - **Modelos enviesados**: Modelos treinados com dados duplicados podem aprender padrões incorretos, levando a previsões imprecisas e decisões tendenciosas.
#
# - **Desperdício de tempo e recursos**: Treinar um modelo com dados duplicados é como tentar construir uma casa em cima de areia: o esforço é em vão e o resultado é instável.
#
# - **Dificuldade na análise**: A presença de dados duplicados dificulta a análise dos dados e a extração de insights relevantes.

# %% [markdown]
# ```python
# # Exemplos Práticos para identificar registros duplicados
# '''verificar cada linha se representa registro duplicado'''
# print(df.duplicated())

# %%
print(df.duplicated())
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9645    False
# 9646    False
# 9647    False
# 9648    False
# 9649    False
# Length: 9650, dtype: bool

# %% [markdown]
# ```python
# '''Valores Booleanos 'True' possuem valor 1 enquanto 'False' possuem valor 0,
# podemos então somar a quantidade de linhas de registros duplicatos encontrados'''
# reg_duplos=df.duplicated().sum()
# print(f"\n Quantidade de registros duplicados:{reg_duplos}")

# %%
reg_duplos=df.duplicated().sum()
print(f"\n Quantidade de registros duplicados:{reg_duplos}")
# Out:
#  Quantidade de registros duplicados:6

# %% [markdown]
# ```markdown
# Vamos visualizar os registros. Para isto é comum usarmos os index dos registros.
# ```python
# #vamos encontrar s registros duplicados
# df[df.duplicated()==True]
# ```

# %%
df[df.duplicated()]
# Out:
#          Retailer  Retailer ID Invoice Date     Region           State  \
# 9          Kohl's      1185732   2020-01-21  Northeast        New York
# 2370       Kohl's      1185732   2021-01-06  Southeast  South Carolina
# 3719       Kohl's      1185732   2021-10-15  Northeast   Massachusetts
# 3847       Kohl's      1185732   2021-07-17  Northeast   New Hampshire
# 7928       Kohl's      1185732   2020-11-12       West      California
# 9639  Foot Locker      1128299   2021-12-17  Northeast   New Hampshire
#
#                City                    Product  Price per Unit  Units Sold  \
# 9          New York    Women's Street Footwear            40.0         950
# 2370     Charleston  Women's Athletic Footwear            30.0         575
# 3719         Boston    Men's Athletic Footwear            55.0         225
# 3847     Manchester    Women's Street Footwear            55.0         375
# 7928  San Francisco            Women's Apparel            33.0         210
# ...

# %% [markdown]
# ######Existem funções do `pandas` que facilitam as tarefas de limpeza e pré-processamento dos dados. O comando de retirada de duplicatas é descrito abaixo, perceba que `inplace==True` (alterar o objeto local) é usado como parâmetro.
#
# ```python
# df.drop_duplicates(inplace=True)
#
# ```

# %%
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9644 entries, 0 to 9649
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Retailer          9644 non-null   object
#  1   Retailer ID       9644 non-null   int64
#  2   Invoice Date      9644 non-null   datetime64[ns]
#  3   Region            9644 non-null   object
#  4   State             9644 non-null   object
#  5   City              9644 non-null   object
#  6   Product           9637 non-null   object
#  7   Price per Unit    9634 non-null   float64
#  8   Units Sold        9644 non-null   int64
#  9   Total Sales       9639 non-null   float64
#  10  Operating Profit  9641 non-null   float64
#  11  Operating Margin  9630 non-null   float64
#  12  Sales Method      9644 non-null   object
# dtypes: datetime64[ns](1), float64(4), int64(2), object(6)
# memory usage: 1.0+ MB

# %% [markdown]
# ###Existem ainda dados que diferem entre as colunas. Algumas possuem mais registros que outras, retirando os registros duplicatos, agora temos que entender como resolver a situação.
#
# - Vamos listar a quantidade de registros vazios por coluna da seguinte forma
#
# ```python
# df.isna().sum()
#
# ```

# %%
df.isna().sum()
# Out:
# Retailer             0
# Retailer ID          0
# Invoice Date         0
# Region               0
# State                0
# City                 0
# Product              7
# Price per Unit      10
# Units Sold           0
# Total Sales          5
# Operating Profit     3
# Operating Margin    14
# Sales Method         0
# dtype: int64

# %% [markdown]
# ###Vamos identificar alguns registros faltantes e tentar compreender as origens destas falhas e a melhor de forma de resolvê-las. Aqui faremos de uma forma um pouco diferente.
#
# - Vamos listar algumas linhas de registros faltantes, mas para isso, vamos identificar os índices dos registros faltantes, isto é, somamos no sentido das colunas *axis=1* (imagine uma sobreposição) onde os dados estejam quando faltantes (**isna**) seja verdadeiro (``True``). O *index* é o atributo índice da classe *Series*.
#
#
# ```python
# df.isna().sum(axis=1).index
# ```

# %%
df.isna()
# Out:
#       Retailer  Retailer ID  Invoice Date  Region  State   City  Product  \
# 0        False        False         False   False  False  False    False
# 1        False        False         False   False  False  False    False
# 2        False        False         False   False  False  False    False
# 3        False        False         False   False  False  False    False
# 4        False        False         False   False  False  False    False
# ...        ...          ...           ...     ...    ...    ...      ...
# 9645     False        False         False   False  False  False    False
# 9646     False        False         False   False  False  False    False
# 9647     False        False         False   False  False  False    False
# 9648     False        False         False   False  False  False    False
# 9649     False        False         False   False  False  False    False
#
#       Price per Unit  Units Sold  Total Sales  Operating Profit  \
# ...

# %%
df.isna().sum(axis=1)
# Out:
# 0       0
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 9645    0
# 9646    0
# 9647    0
# 9648    0
# 9649    0
# Length: 9644, dtype: int64

# %%
df.isna().sum(axis=1)==1
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 9645    False
# 9646    False
# 9647    False
# 9648    False
# 9649    False
# Length: 9644, dtype: bool

# %%
mascara_faltantes=df.isna().sum(axis=1)!=0

# %% [markdown]
# ### Identificandos quantidade de registros faltantes por coluna (somando linhas)
# ```python
# df.isna().sum(axis=0)
# ```

# %%
df.isna().sum(axis=0)
# Out:
# Retailer             0
# Retailer ID          0
# Invoice Date         0
# Region               0
# State                0
# City                 0
# Product              7
# Price per Unit      10
# Units Sold           0
# Total Sales          5
# Operating Profit     3
# Operating Margin    14
# Sales Method         0
# dtype: int64

# %% [markdown]
# ###Vamos utilizar agora o método loc do pandas, ele serve para localizar valores criando *SLICES* ou *RECORTES*.

# %% [markdown]
# - Para realizar cortes ou *slices* determinamos os *índices* ou *máscara booleana* para realizar a filtragem das linhas e definimos a(s) coluna(s).
#
# O resultado pode ser uma `pd.Series` ou um `pd.DataFrame`.
#
# Faremos:
# ```python
# df.loc[[0,1,2],'Operating Profit']
# ```

# %%
df.loc[[0,1,2],'Operating Profit']
# Out:
# 0    30000.0
# 1    15000.0
# 2    14000.0
# Name: Operating Profit, dtype: float64

# %%
df.loc[[0,1,2],['Retailer','Operating Profit']]
# Out:
#   Retailer  Operating Profit
# 0   Kohl's           30000.0
# 1   Kohl's           15000.0
# 2   Kohl's           14000.0

# %%
df.loc[mascara_faltantes,:].head(8)
# Out:
#    Retailer  Retailer ID Invoice Date     Region     State      City  \
# 3    Kohl's      1185732   2020-01-04  Northeast  New York  New York
# 6    Kohl's      1185732   2020-01-07  Northeast  New York  New York
# 7    Kohl's      1185732   2020-01-08  Northeast  New York  New York
# 16   Kohl's      1185732   2020-01-28  Northeast  New York  New York
# 30   Kohl's      1185732   2020-03-03  Northeast  New York  New York
# 38   Kohl's      1185732   2020-03-11  Northeast  New York  New York
# 45   Kohl's      1185732   2020-03-18  Northeast  New York  New York
# 62   Kohl's      1185732   2020-05-02  Northeast  New York  New York
#
#                       Product  Price per Unit  Units Sold  Total Sales  \
# 3   Women's Athletic Footwear            45.0         850      38250.0
# 6       Men's Street Footwear            50.0        1250      62500.0
# 7                         NaN            50.0         900      45000.0
# ...

# %% [markdown]
# ### É possível ainda realizar *slice* a partir da numeração de índices e colunas, isto é da ordenação, veja:
#
# ```python
# df.iloc[:10,:] # considerando do indice 0 até 10 e todas as colunas (:)
#
# df.iloc[:,:3] # considerando todas as linhas e até a 3º coluna (:3)
#
# df.iloc[[0,2,3],8] # considerando uma lista de índices e uma ou mais colunas
# ```

# %%
df.iloc[:10,:8]
# Out:
#    Retailer  Retailer ID Invoice Date     Region     State      City  \
# 0    Kohl's      1185732   2020-01-01  Northeast  New York  New York
# 1    Kohl's      1185732   2020-01-02  Northeast  New York  New York
# 2    Kohl's      1185732   2020-01-03  Northeast  New York  New York
# 3    Kohl's      1185732   2020-01-04  Northeast  New York  New York
# 4    Kohl's      1185732   2020-01-05  Northeast  New York  New York
# 5    Kohl's      1185732   2020-01-06  Northeast  New York  New York
# 6    Kohl's      1185732   2020-01-07  Northeast  New York  New York
# 7    Kohl's      1185732   2020-01-08  Northeast  New York  New York
# 8    Kohl's      1185732   2020-01-21  Northeast  New York  New York
# 10   Kohl's      1185732   2020-01-22  Northeast  New York  New York
#
#                       Product  Price per Unit
# 0       Men's Street Footwear            50.0
# 1     Men's Athletic Footwear            50.0
# 2     Women's Street Footwear            40.0
# ...

# %%
df.iloc[:15,:8]
# Out:
#    Retailer  Retailer ID Invoice Date     Region     State      City  \
# 0    Kohl's      1185732   2020-01-01  Northeast  New York  New York
# 1    Kohl's      1185732   2020-01-02  Northeast  New York  New York
# 2    Kohl's      1185732   2020-01-03  Northeast  New York  New York
# 3    Kohl's      1185732   2020-01-04  Northeast  New York  New York
# 4    Kohl's      1185732   2020-01-05  Northeast  New York  New York
# 5    Kohl's      1185732   2020-01-06  Northeast  New York  New York
# 6    Kohl's      1185732   2020-01-07  Northeast  New York  New York
# 7    Kohl's      1185732   2020-01-08  Northeast  New York  New York
# 8    Kohl's      1185732   2020-01-21  Northeast  New York  New York
# 10   Kohl's      1185732   2020-01-22  Northeast  New York  New York
# 11   Kohl's      1185732   2020-01-23  Northeast  New York  New York
# 12   Kohl's      1185732   2020-01-24  Northeast  New York  New York
# 13   Kohl's      1185732   2020-01-25  Northeast  New York  New York
# ...

# %% [markdown]
# ####Repare que os dados faltantes vêm de campos calculados, isto é, a partir das outras colunas é possível incorporá-los. Mas e quando isso não ocorre?
#
# ⏳É necessário recorrer a regras e estratégias de implementação dos dados faltantes ou até excluir os registros.
#
# Exemplos de contextos e possíveis estratégias:
#
# * 🗨 Você possui dados de vendas, alguns poucos registros mais atuais de ticket médio de alguns clientes especificamente foram perdidos. Uma possibilidade é acessar o histórico de cada cliente e calcular a média, moda ou mediana dos últimos registros restantes.
#
# * ❔ Métodos de inserção de dados a partir da última observação válida e estatísticas podem ser utilizadas.
# <br>Ex: Maria tem um histórico de notas frequentemente **altas** no colégio, dada uma nota perdida no banco de dados, qual a probabilidade de ser uma nota alta, média ou abaixo da média?
#
# ✅ É necessário sempre buscar a melhor opção que traga integridade dos dados. A perda significativa de optar pela exclusão dos registros faltantes talvez não seja a melhor opção!
#
# Para cada tipo de dado faltante adotaremos uma estratégia:
#
# - Preço por Unidade: Calcular Total de Venda/Unidades Vendidas
#
# - Total de Vendas: Calcular Preço Unitário x Unidades Vendidas
#
# - Cálculo do Lucro: Calcular Margem x Total de Venda
#
# - Cálculo da Margem de Lucro: Calcular Lucro/ Total de Venda
#
#
# ####<font color=red>`Atenção! Calcular uma coluna com outras colunas que possuem dados faltantes/NaN (ao menos uma delas) irá resultar em uma coluna também com dados faltantes`<font/>.

# %% [markdown]
# 1. Preço por Unidade faltante
#
# ```python
# #1º Crie a Máscara Booleana
#
# mascara_unidade=df['Price per Unit'].isna()
#
# #2º Altere usando método slice 'loc'
#
# df.loc[mascara_unidade,"Price per Unit"]=df.loc[mascara_unidade,"Total Sales"]/df.loc[mascara_unidade,"Units Sold"]
#
# ```

# %%
mascara_unidade=df['Price per Unit'].isna()

# %%
mascara_unidade
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9645    False
# 9646    False
# 9647    False
# 9648    False
# 9649    False
# Name: Price per Unit, Length: 9644, dtype: bool

# %%
df.loc[mascara_unidade,"Price per Unit"]=df.loc[mascara_unidade,"Total Sales"]/df.loc[mascara_unidade,"Units Sold"]

# %% [markdown]
# 2. Total de Vendas
#
# ```python
# #1º Crie a Máscara Booleana
#
# mascara_vendas=df['Total Sales'].isna()
#
# #2º Altere usando método slice 'loc'
#
# df.loc[mascara_vendas,"Total Sales"]=df.loc[mascara_vendas,"Operating Profit"]/df.loc[mascara_vendas,"Operating Margin"]
#
# ```

# %%
mascara_vendas=df['Total Sales'].isna()
df.loc[mascara_vendas,"Total Sales"]=df.loc[mascara_vendas,"Operating Profit"]/df.loc[mascara_vendas,"Operating Margin"]

# %% [markdown]
# 3. Lucro
#
# ```python
# #1º Crie a Máscara Booleana
#
# mascara_lucro=df['Operating Profit'].isna()
#
# #2º Altere usando método slice 'loc'
#
# df.loc[mascara_lucro,"Operating Profit"]=df.loc[mascara_lucro,"Operating Margin"]*df.loc[mascara_lucro,"Total Sales"]
# ```

# %%
mascara_lucro=df['Operating Profit'].isna()
df.loc[mascara_lucro,"Operating Profit"]=df.loc[mascara_lucro,"Operating Margin"]*df.loc[mascara_lucro,"Total Sales"]

# %% [markdown]
# 4. Margem de Lucro
#
# ```python
# #1º Crie a Máscara Booleana
#
# mascara_margem=df['Operating Margin'].isna()
#
# #2º Altere usando método slice 'loc'
#
# df.loc[mascara_margem,"Operating Margin"]=df.loc[mascara_margem,"Operating Profit"]/df.loc[mascara_margem,"Total Sales"]
# ```

# %%
mascara_margem=df['Operating Margin'].isna()
df.loc[mascara_margem,"Operating Margin"]=df.loc[mascara_margem,"Operating Profit"]/df.loc[mascara_margem,"Total Sales"]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9644 entries, 0 to 9649
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Retailer          9644 non-null   object
#  1   Retailer ID       9644 non-null   int64
#  2   Invoice Date      9644 non-null   datetime64[ns]
#  3   Region            9644 non-null   object
#  4   State             9644 non-null   object
#  5   City              9644 non-null   object
#  6   Product           9637 non-null   object
#  7   Price per Unit    9644 non-null   float64
#  8   Units Sold        9644 non-null   int64
#  9   Total Sales       9644 non-null   float64
#  10  Operating Profit  9644 non-null   float64
#  11  Operating Margin  9644 non-null   float64
#  12  Sales Method      9644 non-null   object
# dtypes: datetime64[ns](1), float64(4), int64(2), object(6)
# memory usage: 1.3+ MB

# %% [markdown]
# ####Repare que ainda existem dados faltantes, no caso a descrição de produtos. Neste caso não é viável excluir o registro (row/linha) pois prejudicará análises futuras (vendas por varejista/retailer por exemplo).
#
#   🗨 Para resolução deste problema nada trivial, passaremos a usar métodos estatísticas e análises de visualização de dados

# %%
df[df['Product'].isna()]
# Out:
#            Retailer  Retailer ID Invoice Date     Region         State  \
# 7            Kohl's      1185732   2020-01-08  Northeast      New York
# 451          Kohl's      1185732   2021-11-13  Northeast  Pennsylvania
# 1825         Kohl's      1185732   2021-06-11       West          Utah
# 4052         Kohl's      1185732   2020-12-29       West    California
# 9147         Kohl's      1185732   2021-02-21      South      Arkansas
# 9209         Kohl's      1185732   2021-01-23      South      Arkansas
# 9295  Sports Direct      1197831   2021-03-03  Northeast   Connecticut
#
#                 City Product  Price per Unit  Units Sold  Total Sales  \
# 7           New York     NaN            50.0         900      45000.0
# 451     Philadelphia     NaN            60.0          75       4500.0
# 1825  Salt Lake City     NaN            40.0         575      23000.0
# 4052   San Francisco     NaN            59.0         152       8968.0
# ...

# %% [markdown]
# ### Estatística Descritiva e Introdução à Visualização de Dados
#
# ☝Repare que a maior parte dos registros faltantes vem do Varejista/Retailer **Kohl's**. Portanto, vamos explorar este varejista especificamente.
#
# ❗Atenção para dados no tempo, mudanças podem ocorrer quanto a fornecedores, vendas, produtos❗
#
# Para isto vamos usar alguns métodos de agrupamento e cálculo de medidas de estatística descritiva, medidas de posição e de variância.
#
# Para agrupar dados usamos o método `GROUP BY` do `pd.DataFrame`, desta forma:
#
# ```python
#
# '''PARA REALIZAR UM ESTUDO COMPLEXO USAREMOS A SEGUINTE NOTAÇÃO:'''
#
# df[mascara_booleana].groupby(by='Coluna a ser agrupada')['Coluna de cálculo'] +
#
# .count() # para contagem de registros
#
# .sum() # para soma de todas as colunas, obs: para strings o pandas realiza a concatenação das frases ou strings
#
# .mean() # para média de todas as colunas (possíveis de calcular, isto é, valores númericos)
#
# .std() # para desvio padrão de todas as colunas (possíveis de calcular, isto é, valores númericos)
# ```

# %%
mask=(df['Invoice Date']<"01/01/2021") & (df['Retailer']=="Kohl's")

# %%
df[mask].groupby('Product')["Price per Unit"].count()
# Out:
# Product
# Men's Apparel                215
# Men's Athletic Footwear      215
# Men's Street Footwear        219
# Women's Apparel              219
# Women's Athletic Footwear    216
# Women's Street Footwear      216
# Name: Price per Unit, dtype: int64

# %%
df[mask].groupby('Product')["Price per Unit"].mean()
# Out:
# Product
# Men's Apparel                54.725581
# Men's Athletic Footwear      49.967442
# Men's Street Footwear        47.757991
# Women's Apparel              57.086758
# Women's Athletic Footwear    47.236111
# Women's Street Footwear      46.935185
# Name: Price per Unit, dtype: float64

# %%
df[mask].groupby('Product')["Price per Unit"].std()
# Out:
# Product
# Men's Apparel                12.663290
# Men's Athletic Footwear      12.614109
# Men's Street Footwear        13.384603
# Women's Apparel              16.290842
# Women's Athletic Footwear    12.213785
# Women's Street Footwear      13.310442
# Name: Price per Unit, dtype: float64

# %%
df[mask].groupby('Product')[["Price per Unit"]].boxplot(layout=(1,6), figsize=(20,5))
# Out:
# Men's Apparel                     Axes(0.1,0.15;0.114286x0.75)
# Men's Athletic Footwear      Axes(0.237143,0.15;0.114286x0.75)
# Men's Street Footwear        Axes(0.374286,0.15;0.114286x0.75)
# Women's Apparel              Axes(0.511429,0.15;0.114286x0.75)
# Women's Athletic Footwear    Axes(0.648571,0.15;0.114286x0.75)
# Women's Street Footwear      Axes(0.785714,0.15;0.114286x0.75)
# dtype: object

# %%
df[mask].groupby('Product')[["Operating Margin"]].boxplot(layout=(1,6), figsize=(20,5))
# Out:
# Men's Apparel                     Axes(0.1,0.15;0.114286x0.75)
# Men's Athletic Footwear      Axes(0.237143,0.15;0.114286x0.75)
# Men's Street Footwear        Axes(0.374286,0.15;0.114286x0.75)
# Women's Apparel              Axes(0.511429,0.15;0.114286x0.75)
# Women's Athletic Footwear    Axes(0.648571,0.15;0.114286x0.75)
# Women's Street Footwear      Axes(0.785714,0.15;0.114286x0.75)
# dtype: object

# %%
df[mask].pivot_table(index="Product",columns="Sales Method",values="Total Sales",aggfunc='count')
# Out:
# Sales Method               In-store  Online  Outlet
# Product
# Men's Apparel                    48      87      80
# Men's Athletic Footwear          47      88      80
# Men's Street Footwear            48      89      82
# Women's Apparel                  48      89      82
# Women's Athletic Footwear        48      88      80
# Women's Street Footwear          48      88      80

# %%
df[mask].pivot_table(index="Product",columns="Sales Method",values="Price per Unit",aggfunc='mean')
# Out:
# Sales Method                In-store     Online     Outlet
# Product
# Men's Apparel              64.687500  55.977011  47.387500
# Men's Athletic Footwear    58.617021  51.102273  43.637500
# Men's Street Footwear      56.145833  48.943820  41.560976
# Women's Apparel            66.875000  58.415730  49.914634
# Women's Athletic Footwear  55.104167  48.329545  41.312500
# Women's Street Footwear    54.895833  47.704545  41.312500

# %%
df[mask].pivot_table(index="Product",columns="Sales Method",values="Price per Unit",aggfunc='std')
# Out:
# Sales Method                In-store     Online     Outlet
# Product
# Men's Apparel              11.411372  11.329091  10.032219
# Men's Athletic Footwear    13.216513  11.494166   9.863940
# Men's Street Footwear      12.933528  12.216196  11.867684
# Women's Apparel            17.583388  15.371764  12.936885
# Women's Athletic Footwear  13.025735  11.673451   8.971959
# Women's Street Footwear    14.928538  12.671952  10.077665

# %%
df[mask].pivot_table(index="Product",columns="Sales Method",values="Units Sold",aggfunc='mean')
# Out:
# Sales Method                 In-store      Online    Outlet
# Product
# Men's Apparel              431.250000  130.689655  362.5625
# Men's Athletic Footwear    585.638298  175.500000  473.6375
# Men's Street Footwear      734.479167  208.820225  553.0000
# Women's Apparel            544.270833  169.573034  475.5000
# Women's Athletic Footwear  451.041667  137.363636  380.4875
# Women's Street Footwear    527.500000  163.113636  451.4625

# %%
df[mask].pivot_table(index="Product",columns="Sales Method",values="Units Sold", aggfunc='mean')
# Out:
# Sales Method                 In-store      Online    Outlet
# Product
# Men's Apparel              431.250000  130.689655  362.5625
# Men's Athletic Footwear    585.638298  175.500000  473.6375
# Men's Street Footwear      734.479167  208.820225  553.0000
# Women's Apparel            544.270833  169.573034  475.5000
# Women's Athletic Footwear  451.041667  137.363636  380.4875
# Women's Street Footwear    527.500000  163.113636  451.4625

# %%
df[mask].pivot_table(index="Product",columns="Sales Method",values="Units Sold",aggfunc='std')
# Out:
# Sales Method                 In-store     Online      Outlet
# Product
# Men's Apparel              235.398033  73.148989  268.557650
# Men's Athletic Footwear    221.699505  70.748868  303.870152
# Men's Street Footwear      250.474527  71.318358  338.549119
# Women's Apparel            228.445230  75.279009  312.488706
# Women's Athletic Footwear  216.165712  67.723946  264.232876
# Women's Street Footwear    205.086904  72.026246  299.871067

# %% [markdown]
# ###⭐ BÔNUS - USANDO ALGORITMO DE APRENDIZADO DE MÁQUINA PARA CATEGORIZAR VALORES FALTANTES⭐###
#
# ##🌳 USAREMOS DECISION TREE (UM ALGORITMO DE APRENDIZADO DE MÁQUINA SUPERVISIONADO) PARA ENCONTRARMOS OS VALORES FALTANTES DE DESCRIÇÃO DE PRODUTO VENDIDO🌳##
#
# Link: [Material Árvores INF](https://docs.google.com/presentation/d/1CSQNK59_2olyy6BoLbQwtL7HVFR8hbwe/edit?usp=sharing&ouid=111794446252640311776&rtpof=true&sd=true)
#
#
# ## Get Dummies! Uma maneira de transformar colunas categóricas em Binárias!
#
# Converte variáveis **categóricas** em dummy!
# ❗ ATENÇÃO VARIÁVEIS NUMÉRICAS COMO FLOAT E INT DO DATAFRAME NÃO SERÃO CONVERTIDAS, A NÃO SER QUE VOCÊ IDENTIFIQUE A COLUNA NO MÉTODO❗
#
# NÃO GERA DUMMIES:
# ```python
# df_teste=pd.DataFrame([[10.5,11],[20,50],[24,58]],columns='A B'.split(" "))
# print(df_teste.info())
# print(pd.get_dummies(df_teste)
# ```
# GERA DUMMIES A PARTIR DE DADOS INTEIROS:
# ```python
# df_teste=pd.DataFrame([[10.5,11],[20,50],[24,58]],columns='A B'.split(" "))
# print(df_teste.info())
# print(pd.get_dummies(df_teste["B"])) #INDIQUEI A COLUNA "B"
# ```
#
#
# Documentação: [get_dummies](https://pandas.pydata.org/docs/reference/api/pandas.get_dummies.html)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Para dados tipo

# %%
pd.get_dummies(df).head()
# Out:
#    Retailer ID Invoice Date  Price per Unit  Units Sold  Total Sales  \
# 0      1185732   2020-01-01            50.0        1200      60000.0
# 1      1185732   2020-01-02            50.0        1000      50000.0
# 2      1185732   2020-01-03            40.0        1000      40000.0
# 3      1185732   2020-01-04            45.0         850      38250.0
# 4      1185732   2020-01-05            60.0         900      54000.0
#
#    Operating Profit  Operating Margin  Retailer_Amazon  Retailer_Foot Locker  \
# 0           30000.0              0.50            False                 False
# 1           15000.0              0.30            False                 False
# 2           14000.0              0.35            False                 False
# 3           13387.5              0.35            False                 False
# 4           16200.0              0.30            False                 False
#
#    Retailer_Kohl's  ...  City_Wilmington  Product_Men's Apparel  \
# ...

# %%
data_=df.dropna()

# %%
data_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9637 entries, 0 to 9649
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Retailer          9637 non-null   object
#  1   Retailer ID       9637 non-null   int64
#  2   Invoice Date      9637 non-null   datetime64[ns]
#  3   Region            9637 non-null   object
#  4   State             9637 non-null   object
#  5   City              9637 non-null   object
#  6   Product           9637 non-null   object
#  7   Price per Unit    9637 non-null   float64
#  8   Units Sold        9637 non-null   int64
#  9   Total Sales       9637 non-null   float64
#  10  Operating Profit  9637 non-null   float64
#  11  Operating Margin  9637 non-null   float64
#  12  Sales Method      9637 non-null   object
# dtypes: datetime64[ns](1), float64(4), int64(2), object(6)
# memory usage: 1.0+ MB

# %% [markdown]
# ### Preparando dados de treino!
#
# #### Usaremos todos os dados não faltantes para TREINAR ou TESTAR nossa árvore, queremos que o nosso modelo APRENDA (MACHINE LEARNING) alguns padrões.
#
# ❗Modelos de aprendizado de máquina precisam aprender sobre os dados (Machine Learning), neste caso utilizamos apenas para inputar dados, não testaremos métricas de classificação e nem desempenho do modelo ❗
# ```python
# df_Train=pd.get_dummies(data_.iloc[:,[3,4,5,7,8,9,10,11,12]])
# ```
#
# As colunas 3,4,5,7,8,9,10,11,12 são relativas aos dados categóricos que serão transformados em Dummies

# %%
df_Train=pd.get_dummies(data_.iloc[:,[3,4,5,7,8,9,10,11,12]])

# %%
df_Train.shape
# Out:
# (9637, 115)

# %% [markdown]
# ### Criando Modelo Árvore de Decisão para Classificação
#
# Para isto faremos a importação e definição de parâmetros:
# ```python
# from sklearn.tree import DecisionTreeClassifier
# from sklearn.model_selection import train_test_split
# clf = DecisionTreeClassifier(random_state=0,max_depth=5)
# ```
#
# Entraremos com os dados faltantes e dividiremos em treino (75%) e teste (25%).
# Para isto:
# ```python
# X_train, X_test, y_train, y_test = train_test_split(df_Train, data_.iloc[:,6], test_size=0.25, random_state=0)
# ```

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
clf = DecisionTreeClassifier(random_state=0,max_depth=5)

# %%
X_train, X_test, y_train, y_test = train_test_split(df_Train, data_.iloc[:,6], test_size=0.25, random_state=0)

# %% [markdown]
# ### Vamos treinar com o método ```.fit```
# ```python
# clf.fit(X_train,y_train)
# ```

# %%
clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, random_state=0)

# %% [markdown]
# ### Recortando os dados em que o campo "Produtos" está faltando!
#
# Encontraremos os indices:
# ```python
# indices_nan=df[df['Product'].isna()].index
# ```
# Criamos dummies da mesma forma:
#
# ```python
# data_pred=pd.get_dummies(df.iloc[:,[3,4,5,7,8,9,10,11,12]]).loc[indices_nan,:]
# ```

# %%
indices_nan=df[df['Product'].isna()].index

# %%
data_pred=pd.get_dummies(df.iloc[:,[3,4,5,7,8,9,10,11,12]]).loc[indices_nan,:]

# %% [markdown]
# #### Reajustaremos o formato dos dados para obtermos uma interação que:
#
# - Para cada registro faltante (linha com dummies prontas) faremos o nosso modelo classificar o produto. Precisamos de um formato (1,115), 1 linhas e 115 colunas! Veja um exemplo:
#
# ```python
# data_pred.values[0].reshape(1,-1).shape # para ver o shape
# ```
# ou
# ```python
# data_pred.values[0].reshape(1,-1) # para ver os valores
# ```

# %%
data_pred.values[0].reshape(1,-1)
# Out:
# array([[50.0, 900, 45000.0, 13500.0, 0.3, False, True, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, True, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, True, False, False, False,
#         False, False, False, False, False, False, False, False, False,
#         False, False, False, False, False, False, True]], dtype=object)

# %% [markdown]
# #### Passos
# - Faremos uma iteração sobre os dados faltantes (cada linha).
# - A reorganização do shape em (1,155).
# - Entraremos com os dados como input e printaremos os resultados.

# %%
from sklearn.base import warnings
warnings.filterwarnings("ignore", category=UserWarning)

cont=0
for dados_ in data_pred.values:
  dados_=dados_.reshape(1,-1) #transformar para 2D
  resultado=clf.predict(dados_)
  print(f"Para o índice {indices_nan[cont]}, a previsão usando DecisionTreeClassifier é {resultado[0]}")
  cont+=1
# Out:
# Para o índice 7, a previsão usando DecisionTreeClassifier é Men's Street Footwear
# Para o índice 451, a previsão usando DecisionTreeClassifier é Men's Apparel
# Para o índice 1825, a previsão usando DecisionTreeClassifier é Women's Apparel
# Para o índice 4052, a previsão usando DecisionTreeClassifier é Women's Apparel
# Para o índice 9147, a previsão usando DecisionTreeClassifier é Men's Street Footwear
# Para o índice 9209, a previsão usando DecisionTreeClassifier é Men's Street Footwear
# Para o índice 9295, a previsão usando DecisionTreeClassifier é Women's Athletic Footwear

# %%
clf.predict(data_pred.iloc[2,:].values.reshape(1,-1))
# Out:
# array(["Women's Apparel"], dtype=object)

# %% [markdown]
# ## ⭐ BÔNUS ⭐ - VAMOS PLOTAR A 🌳ÁRVORE DE DECISÃO

# %%
import graphviz
from sklearn import tree

# %%
dot_data=tree.export_graphviz(clf,out_file=None,filled=True,rounded=True,feature_names=clf.feature_names_in_, \
                              proportion=True,class_names=clf.classes_)

# %%
graphviz.Source(dot_data)

# %% [markdown]
# ### Salvando ou Baixando arquivos
#
# Formatos:
# 1. Salvar em CSV:
# df.to_csv('meus_dados.csv', index=False)
# 2. Salvar em Excel (.xlsx):
# df.to_excel('meus_dados.xlsx', index=False)
# 3. Salvar em JSON:
# df.to_json('meus_dados.json', orient='records', lines=True)
# 4. Salvar em Parquet:
# df.to_parquet('meus_dados.parquet', index=False)
#
# ####Salvar arquivos no Google Drive:
# Para salvar arquivos diretamente no Google Drive.
#
# ```python
# import pandas as pd
#
# # Caminho para salvar o arquivo
# caminho_arquivo = '/content/drive/My Drive/meus_dados.csv'
#
# # Salvando o DataFrame no Google Drive no formato csv
# df.to_csv(caminho_arquivo, index=False)
# ```
#
# #### Baixar arquivos diretamente para o seu computador:
# Se você preferir baixar os arquivos diretamente, pode usar o código abaixo:
#
# ```python
# from google.colab import files
#
# # Salvando localmente no Colab
# df.to_csv('meus_dados.csv', index=False)
#
# # Fazendo download para o computador
# files.download('meus_dados.csv')
# ```

# %%
#Exemplo
from google.colab import files

df.to_excel("saida.xlsx")
files.download("saida.xlsx")
